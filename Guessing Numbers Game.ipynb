# %%
import random

exit = 0
guessCount = 0
number = genRandom()
print("Let's play a guessing game! Type exit to quit.\n")

def genRandom():
    num = random.randrange(1,10,1)
    return num

def userInput(n, gC):
    inp = input("What is your guess? ")
    if inp == 'exit':
        return gC, inp, 1
    gC = gC + 1
    return gC, int(inp), 0
    
def checkGuess(g,n):
    if g == n:
        return 1
    return 0

while exit != 1:
    guess = ''
    print("What number am I thinking of? \n")
    guessCount, guess, exit = userInput(number, guessCount)
    compare = checkGuess(guess,number)
    if compare == 1:
        print(f"You guessed it! It took you {guessCount} tries.\n Let's play again! ")
        guessCount = 0
        number = genRandom()
# Out:
# Let's play a guessing game! Type exit to quit.
#
# What number am I thinking of?
#
# What is your guess? 1
# What number am I thinking of?
#
# What is your guess? 2
# You guessed it! It took you 2 tries.
#  Let's play again!
# What number am I thinking of?
#
# What is your guess? 3
# What number am I thinking of?
#
# What is your guess? 4
# What number am I thinking of?
#
# What is your guess? 5
# What number am I thinking of?
#
# What is your guess? 6
# You guessed it! It took you 4 tries.
#  Let's play again!
# What number am I thinking of?
#
# What is your guess? 7
# What number am I thinking of?
#
# What is your guess? 8
# What number am I thinking of?
#
# What is your guess? 9
# What number am I thinking of?
#
# What is your guess? 1
# You guessed it! It took you 4 tries.
#  Let's play again!
# What number am I thinking of?
#
# What is your guess? 1
# What number am I thinking of?
#
# What is your guess? 2
# What number am I thinking of?
#
# What is your guess? 3
# What number am I thinking of?
#
# What is your guess? 4
# What number am I thinking of?
#
# What is your guess? 5
# What number am I thinking of?
#
# What is your guess? 6
# What number am I thinking of?
#
# What is your guess? 7
# What number am I thinking of?
#
# What is your guess? 8
# What number am I thinking of?
#
# What is your guess? 9
# You guessed it! It took you 9 tries.
#  Let's play again!
# What number am I thinking of?
